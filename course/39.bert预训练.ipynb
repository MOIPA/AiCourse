# %%
import torch
from torch import nn
from d2l import torch as d2l

# %%
# 加载数据
batch_size, max_len = 512, 64
train_iter, vocab = d2l.load_data_wiki(batch_size, max_len)

# %% [markdown]
# ## 预训练

# %%
# 定义模型
baseSize = 16 # 128 跑不动128 改成16将就看
net = d2l.BERTModel(len(vocab), num_hiddens=baseSize, norm_shape=[baseSize],
                    ffn_num_input=baseSize, ffn_num_hiddens=baseSize*2, num_heads=2,
                    num_layers=2, dropout=0.2, key_size=baseSize, query_size=baseSize,
                    value_size=baseSize, hid_in_features=baseSize, mlm_in_features=baseSize,
                    nsp_in_features=baseSize)
devices = d2l.try_all_gpus()
loss = nn.CrossEntropyLoss()

# %%
# 输入一批次的数据
# 调用模型执行两个预测任务，并计算和真实结果损失
def _get_batch_loss_bert(net, loss, vocab_size, tokens_X,
                         segments_X, valid_lens_x,
                         pred_positions_X, mlm_weights_X,
                         mlm_Y, nsp_y):
    # 前向传播
    _, mlm_Y_hat, nsp_Y_hat = net(tokens_X, segments_X,
                                  valid_lens_x.reshape(-1),
                                  pred_positions_X)
    # 计算遮蔽语言模型损失
    mlm_l = loss(mlm_Y_hat.reshape(-1, vocab_size), mlm_Y.reshape(-1)) *\
    mlm_weights_X.reshape(-1, 1)
    mlm_l = mlm_l.sum() / (mlm_weights_X.sum() + 1e-8)
    # 计算下一句子预测任务的损失
    nsp_l = loss(nsp_Y_hat, nsp_y)
    l = mlm_l + nsp_l
    return mlm_l, nsp_l, l

# %%
# 训练函数
def train_bert(train_iter, net, loss, vocab_size, devices, num_steps):
    net = nn.DataParallel(net, device_ids=devices).to(devices[0])
    trainer = torch.optim.Adam(net.parameters(), lr=0.01)
    step, timer = 0, d2l.Timer()
    animator = d2l.Animator(xlabel='step', ylabel='loss',
                            xlim=[1, num_steps], legend=['mlm', 'nsp'])
    # 遮蔽语言模型损失的和，下一句预测任务损失的和，句子对的数量，计数
    metric = d2l.Accumulator(4)
    num_steps_reached = False
    # 这个num_steps可以理解为epochs
    while step < num_steps and not num_steps_reached:
        for tokens_X, segments_X, valid_lens_x, pred_positions_X,\
            mlm_weights_X, mlm_Y, nsp_y in train_iter:
            # 转移数据到显卡
            tokens_X = tokens_X.to(devices[0])
            segments_X = segments_X.to(devices[0])
            valid_lens_x = valid_lens_x.to(devices[0])
            pred_positions_X = pred_positions_X.to(devices[0])
            mlm_weights_X = mlm_weights_X.to(devices[0])
            mlm_Y, nsp_y = mlm_Y.to(devices[0]), nsp_y.to(devices[0])
            trainer.zero_grad()
            timer.start()
            # 训练
            mlm_l, nsp_l, l = _get_batch_loss_bert(
                net, loss, vocab_size, tokens_X, segments_X, valid_lens_x,
                pred_positions_X, mlm_weights_X, mlm_Y, nsp_y)
            l.backward()
            trainer.step()
            metric.add(mlm_l, nsp_l, tokens_X.shape[0], 1)
            timer.stop()
            animator.add(step + 1, (metric[0] / metric[3], metric[1] / metric[3]))
            step += 1
            if step == num_steps:
                num_steps_reached = True
                break

    print(f'MLM loss {metric[0] / metric[3]:.3f}, '
          f'NSP loss {metric[1] / metric[3]:.3f}')
    print(f'{metric[2] / timer.sum():.1f} sentence pairs/sec on '
          f'{str(devices)}')

# %%
train_bert(train_iter, net, loss, len(vocab), devices, 50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 train_bert(train_iter, net, loss, len(vocab), devices, 5)
#
# Cell In[10], line 13, in train_bert(train_iter, net, loss, vocab_size, devices, num_steps)
#      11 # 这个num_steps可以理解为epochs
#      12 while step < num_steps and not num_steps_reached:
# ---> 13     for tokens_X, segments_X, valid_lens_x, pred_positions_X,\
#      14         mlm_weights_X, mlm_Y, nsp_y in train_iter:
#      15         # 转移数据到显卡
#      16         tokens_X = tokens_X.to(devices[0])
#      17         segments_X = segments_X.to(devices[0])
#
# File d:\Anaconda\envs\d2l-zh\lib\site-packages\torch\utils\data\dataloader.py:435, in DataLoader.__iter__(self)
#     433     return self._iterator
#     434 else:
# --> 435     return self._get_iterator()
#
# ...

# %% [markdown]
# ## 使用bert

# %%
def get_bert_encoding(net, tokens_a, tokens_b=None):
    tokens, segments = d2l.get_tokens_and_segments(tokens_a, tokens_b)
    token_ids = torch.tensor(vocab[tokens], device=devices[0]).unsqueeze(0)
    segments = torch.tensor(segments, device=devices[0]).unsqueeze(0)
    valid_len = torch.tensor(len(tokens), device=devices[0]).unsqueeze(0)
    encoded_X, _, _ = net(token_ids, segments, valid_len)
    return encoded_X

# %%
# 将这句话得到bert的编码表示结果
tokens_a = ['a', 'crane', 'is', 'flying']
encoded_text = get_bert_encoding(net, tokens_a)
# 词元：'<cls>','a','crane','is','flying','<sep>'
encoded_text_cls = encoded_text[:, 0, :]
encoded_text_crane = encoded_text[:, 2, :]
encoded_text.shape, encoded_text_cls.shape, encoded_text_crane[0][:3] # 打印第三个词元的向量的前三个数值

# %%
tokens_a, tokens_b = ['a', 'crane', 'driver', 'came'], ['he', 'just', 'left']
encoded_pair = get_bert_encoding(net, tokens_a, tokens_b)
# 词元：'<cls>','a','crane','driver','came','<sep>','he','just','left','<sep>'
encoded_pair_cls = encoded_pair[:, 0, :]
encoded_pair_crane = encoded_pair[:, 2, :]
encoded_pair.shape, encoded_pair_cls.shape, encoded_pair_crane[0][:3] #和上次打印的数值不同，说明bert对上下文敏感
